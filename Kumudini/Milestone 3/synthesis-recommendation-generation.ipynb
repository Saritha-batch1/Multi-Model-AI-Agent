# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !apt-get install -y poppler-utils

# %%
# !pip install pdfplumber

# %% [markdown]
# **Milestone 2**

# %%
import os
import re
import json
import pandas as pd
import pytesseract
from PIL import Image
from pdf2image import convert_from_path

# ============================================================
# 1. REFERENCE RANGES (CBC)
# ============================================================
REFERENCE_RANGES = {
    "Hemoglobin": {"female": (12.0, 15.5), "male": (14.0, 18.0)},
    "White_Blood_Cells": {"general": (4000, 11000)},
    "Platelet_Count": {"general": (150000, 410000)},
    "Red_Blood_Cells": {"general": (4.5, 5.5)},
    "MCV": {"general": (80, 100)},
    "MCH": {"general": (27, 33)},
    "MCHC": {"general": (32, 36)},
    "RDW": {"general": (11.5, 14.5)}
}

# ============================================================
# 2. OCR REGEX PATTERNS
# ============================================================
CBC_PATTERNS = {
    "Hemoglobin": r"hemoglobin.*?([0-9]+\.?[0-9]*)",
    "Red_Blood_Cells": r"(total rbc count|rbc).*?([0-9]+\.?[0-9]*)",
    "White_Blood_Cells": r"(total wbc count|wbc).*?([0-9]{3,6})",
    "Platelet_Count": r"platelet count.*?([0-9]{5,6})",
    "MCV": r"mcv.*?([0-9]+\.?[0-9]*)",
    "MCH": r"mch.*?([0-9]+\.?[0-9]*)",
    "MCHC": r"(mchc|mean corpuscular hemoglobin concentration).*?([0-9]+\.?[0-9]*)",
    "RDW": r"rdw.*?([0-9]+\.?[0-9]*)"
}

# ============================================================
# 3. PARAMETER CLASSIFICATION (SAFE)
# ============================================================
def classify(param, value, gender="female"):
    if param not in REFERENCE_RANGES:
        return "Unknown"

    gender = gender.lower()
    ranges = REFERENCE_RANGES[param]

    if gender in ranges:
        low, high = ranges[gender]
    elif "general" in ranges:
        low, high = ranges["general"]
    else:
        return "Unknown"

    if value < low:
        return "Low"
    elif value > high:
        return "High"
    return "Normal"

# ============================================================
# 4. CSV PARSER
# ============================================================
def parse_csv(file_path):
    return pd.read_csv(file_path)

# ============================================================
# 5. JSON PARSER
# ============================================================
def parse_json(file_path):
    with open(file_path) as f:
        data = json.load(f)
    return pd.DataFrame(data)

# ============================================================
# 6. PDF / IMAGE PARSER
# ============================================================
def parse_pdf_image(file_path):
    records = []
    images = convert_from_path(file_path) if file_path.lower().endswith(".pdf") else [Image.open(file_path)]

    for img in images:
        text = pytesseract.image_to_string(img).lower()
        record = {}

        for param, pattern in CBC_PATTERNS.items():
            match = re.search(pattern, text, re.DOTALL)
            if match:
                record[param] = float(match.groups()[-1])

        age_match = re.search(r"age[:\s]+(\d+)", text)
        gender_match = re.search(r"(sex|gender)[:\s]+(male|female)", text)

        record["Age"] = int(age_match.group(1)) if age_match else None
        record["Gender"] = gender_match.group(2).capitalize() if gender_match else "Female"

        if len(record) > 2:
            records.append(record)

    return pd.DataFrame(records)

# ============================================================
# 7. STANDARDIZATION + INTERPRETATION
# ============================================================
def standardize_and_classify(df):
    output = []

    for _, row in df.iterrows():
        gender = str(row.get("Gender", "Female")).capitalize()

        patient = {
            "Age": row.get("Age"),
            "Gender": gender,
            "Parameters": {}
        }

        for param in REFERENCE_RANGES:
            if param in row and pd.notna(row[param]):
                value = float(row[param])
                patient["Parameters"][param] = {
                    "value": value,
                    "status": classify(param, value, gender)
                }

        output.append(patient)

    return output

# ============================================================
# 8. PROCESS FILE
# ============================================================
def process_file(file_path):
    if file_path.endswith(".csv"):
        df = parse_csv(file_path)
    elif file_path.endswith(".json"):
        df = parse_json(file_path)
    elif file_path.lower().endswith((".pdf", ".png", ".jpg", ".jpeg", ".webp")):
        df = parse_pdf_image(file_path)
    else:
        raise ValueError("Unsupported file format")

    if df.empty:
        raise ValueError("No valid patient records found")

    return standardize_and_classify(df)

# ============================================================
# 9. SAVE OUTPUT (JSON + CSV)
# ============================================================
def save_outputs(results, base_name):
    with open(f"{base_name}.json", "w") as f:
        json.dump(results, f, indent=4)

    rows = []
    for patient in results:
        for param, details in patient["Parameters"].items():
            rows.append({
                "Age": patient["Age"],
                "Gender": patient["Gender"],
                "Parameter": param,
                "Value": details["value"],
                "Status": details["status"]
            })

    pd.DataFrame(rows).to_csv(f"{base_name}.csv", index=False)

# ============================================================
# 10. MODEL 2 — PATTERN RECOGNITION
# ============================================================
def analyze_patterns(patient):
    params = patient["Parameters"]
    findings, risks = [], []

    if "Hemoglobin" in params and "MCV" in params:
        hb, mcv = params["Hemoglobin"]["value"], params["MCV"]["value"]

        if hb < 12 and mcv < 80:
            findings.append("Microcytic anemia pattern detected.")
            risks.append("Anemia")
        elif hb < 12 and mcv > 100:
            findings.append("Macrocytic anemia pattern detected.")
            risks.append("Anemia")

    if "White_Blood_Cells" in params and params["White_Blood_Cells"]["value"] > 11000:
        findings.append("Possible infection or inflammation.")
        risks.append("Infection")

    if "Platelet_Count" in params and params["Platelet_Count"]["value"] < 150000:
        findings.append("Low platelet count – bleeding risk.")
        risks.append("Bleeding Risk")

    return {"Findings": findings, "Risk_Flags": list(set(risks))}

# ============================================================
# 11. MODEL 3 — CONTEXTUAL ANALYSIS
# ============================================================
def contextual_analysis(patient, model2):
    refined = model2["Findings"].copy()
    age = patient.get("Age")

    if age and age > 60 and model2["Risk_Flags"]:
        refined.append("Advanced age increases clinical relevance.")

    return {"Findings": refined, "Risk_Flags": model2["Risk_Flags"]}

# ============================================================
# 12. FINAL REPORT
# ============================================================
def generate_final_report(patient):
    model2 = analyze_patterns(patient)
    model3 = contextual_analysis(patient, model2)

    recommendations = (
        ["No major abnormalities detected. Maintain a healthy lifestyle."]
        if not model3["Risk_Flags"]
        else ["Consult a physician for further evaluation."]
    )

    return {
        "Patient_Info": {"Age": patient["Age"], "Gender": patient["Gender"]},
        "Parameter_Analysis": patient["Parameters"],
        "Findings": model3["Findings"],
        "Risk_Flags": model3["Risk_Flags"],
        "Recommendations": recommendations,
        
    }

# ============================================================
# 13. ORCHESTRATOR
# ============================================================
def run_milestone_2(results):
    return [generate_final_report(p) for p in results]

# ============================================================
# 14. RUN
# ============================================================
if __name__ == "__main__":
    file_path = "/kaggle/input/reports/blood_count_dataset.csv"

    results = process_file(file_path)
    save_outputs(results, "/kaggle/working/milestone1_output")

    final_reports = run_milestone_2(results)

    with open("/kaggle/working/final_health_report.json", "w") as f:
        json.dump(final_reports, f, indent=4)

    print(json.dumps(final_reports, indent=4))
# Out:
# [
#     {
#         "Patient_Info": {
#             "Age": 68,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 10.4,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 5700.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 180000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 3.7,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 77.0,
#                 "status": "Low"
#             },
#             "MCH": {
#                 "value": 25.0,
#                 "status": "Low"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [
#             "Microcytic anemia pattern detected.",
#             "Advanced age increases clinical relevance."
#         ],
#         "Risk_Flags": [
#             "Anemia"
#         ],
#         "Recommendations": [
#             "Consult a physician for further evaluation."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 25,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.8,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7500.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 320000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.4,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 92.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 30.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 57,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.5,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 8500.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 370000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.1,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 90.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 28,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.7,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 7800.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 290000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.8,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 86.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 38,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.9,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8700.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 380000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.7,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 95.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 47,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.0,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 7000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 260000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.4,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 87.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 28.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 37,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.5,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8700.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 380000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.7,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 95.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 30,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.8,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 250000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.2,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 84.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 27.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 35,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.5,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7100.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 240000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.2,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 84.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 27.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 22,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.6,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7400.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 330000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.6,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 93.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 41,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.2,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 7700.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 310000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.6,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 88.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 34,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.8,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7300.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 280000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.3,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 85.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 28.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 40,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 15.2,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 9200.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 400000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.8,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 96.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 32.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 58,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.4,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 8900.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 390000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.7,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 94.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 34,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.8,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7300.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 280000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.3,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 85.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 28.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 50,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.0,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7600.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 330000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.0,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 90.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 64,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 10.7,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 5900.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 200000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 3.9,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 79.0,
#                 "status": "Low"
#             },
#             "MCH": {
#                 "value": 26.0,
#                 "status": "Low"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [
#             "Microcytic anemia pattern detected.",
#             "Advanced age increases clinical relevance."
#         ],
#         "Risk_Flags": [
#             "Anemia"
#         ],
#         "Recommendations": [
#             "Consult a physician for further evaluation."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 30,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.8,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 250000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.2,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 84.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 27.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 35,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.5,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8500.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 380000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.2,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 94.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 40,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 15.2,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 9200.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 400000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.8,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 96.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 32.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 52,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.2,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8300.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 370000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.4,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 92.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 70,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 10.2,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 5600.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 190000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 3.6,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 76.0,
#                 "status": "Low"
#             },
#             "MCH": {
#                 "value": 24.0,
#                 "status": "Low"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [
#             "Microcytic anemia pattern detected.",
#             "Advanced age increases clinical relevance."
#         ],
#         "Risk_Flags": [
#             "Anemia"
#         ],
#         "Recommendations": [
#             "Consult a physician for further evaluation."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 45,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.2,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 7200.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 270000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.6,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 88.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 28.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 63,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 10.8,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 5900.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 200000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 3.9,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 79.0,
#                 "status": "Low"
#             },
#             "MCH": {
#                 "value": 26.0,
#                 "status": "Low"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [
#             "Microcytic anemia pattern detected.",
#             "Advanced age increases clinical relevance."
#         ],
#         "Risk_Flags": [
#             "Anemia"
#         ],
#         "Recommendations": [
#             "Consult a physician for further evaluation."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 33,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.8,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8200.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 360000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.3,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 91.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 30.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 60,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.0,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 6000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 200000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.0,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 80.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 26.0,
#                 "status": "Low"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 41,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.2,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 7700.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 310000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.6,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 88.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 36,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.7,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8100.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 360000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.5,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 93.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 33,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.8,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8200.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 360000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.3,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 91.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 30.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 39,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 15.1,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 9000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 380000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.7,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 96.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 32.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 27,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.0,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 6900.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 230000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.3,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 85.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 28.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 35,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.7,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 6800.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 250000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.1,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 83.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 27.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 54,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.5,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 8000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 350000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.1,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 90.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 35,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.5,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7100.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 240000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.2,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 84.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 27.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 25,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.9,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7200.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 330000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.3,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 91.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 30.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 40,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.4,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8600.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 370000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.3,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 91.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 30.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 33,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.8,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 6800.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 250000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.2,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 84.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 27.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 36,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.5,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7100.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 240000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.2,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 84.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 27.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 50,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.2,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 8000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 350000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.0,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 90.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 35,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.5,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8500.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 380000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.2,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 94.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 22,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.6,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7400.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 330000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.6,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 93.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 68,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 10.4,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 5700.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 180000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 3.7,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 77.0,
#                 "status": "Low"
#             },
#             "MCH": {
#                 "value": 25.0,
#                 "status": "Low"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [
#             "Microcytic anemia pattern detected.",
#             "Advanced age increases clinical relevance."
#         ],
#         "Risk_Flags": [
#             "Anemia"
#         ],
#         "Recommendations": [
#             "Consult a physician for further evaluation."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 28,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.7,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 7800.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 290000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.8,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 86.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 55,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.8,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 8000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 350000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.3,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 92.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 30.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 48,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.6,
#                 "status": "Normal"
# ...
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.2,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 8000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 350000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.0,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 90.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 43,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.2,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8300.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 360000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.2,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 91.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 30.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 45,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 15.0,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 9000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 400000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.8,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 96.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 32.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 37,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.5,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8700.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 380000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.7,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 95.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 38,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.9,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8700.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 380000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.7,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 95.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 26,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.5,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 7300.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 270000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.7,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 87.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 48,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.2,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7800.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 340000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.1,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 90.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 38,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.4,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 7600.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 310000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.7,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 88.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 28,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.6,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7800.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 310000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.6,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 93.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 40,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.5,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 7700.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 300000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.7,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 88.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 40,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 15.2,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 9200.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 400000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.8,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 96.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 32.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 52,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.5,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 8000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 350000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.3,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 92.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 30.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 30,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.8,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 250000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.2,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 84.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 27.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 60,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.0,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 6000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 200000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.0,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 80.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 26.0,
#                 "status": "Low"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 46,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.2,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8300.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 360000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.4,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 92.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Findings": [],
#         "Risk_Flags": [],
#         "Recommendations": [
#             "No major abnormalities detected. Maintain a healthy lifestyle."
#         ]
#     }
# ]

# %% [markdown]
# **MILESTONE 3**

# %%
import os
import re
import json
import pandas as pd
import pytesseract
from PIL import Image
from pdf2image import convert_from_path

# ============================================================
# 1. REFERENCE RANGES (CBC)
# ============================================================
REFERENCE_RANGES = {
    "Hemoglobin": {"female": (12.0, 15.5), "male": (14.0, 18.0)},
    "White_Blood_Cells": {"general": (4000, 11000)},
    "Platelet_Count": {"general": (150000, 410000)},
    "Red_Blood_Cells": {"general": (4.5, 5.5)},
    "MCV": {"general": (80, 100)},
    "MCH": {"general": (27, 33)},
    "MCHC": {"general": (32, 36)},
    "RDW": {"general": (11.5, 14.5)}
}

# ============================================================
# 2. OCR REGEX PATTERNS
# ============================================================
CBC_PATTERNS = {
    "Hemoglobin": r"hemoglobin.*?([0-9]+\.?[0-9]*)",
    "Red_Blood_Cells": r"(total rbc count|rbc).*?([0-9]+\.?[0-9]*)",
    "White_Blood_Cells": r"(total wbc count|wbc).*?([0-9]{3,6})",
    "Platelet_Count": r"platelet count.*?([0-9]{5,6})",
    "MCV": r"mcv.*?([0-9]+\.?[0-9]*)",
    "MCH": r"mch.*?([0-9]+\.?[0-9]*)",
    "MCHC": r"(mchc|mean corpuscular hemoglobin concentration).*?([0-9]+\.?[0-9]*)",
    "RDW": r"rdw.*?([0-9]+\.?[0-9]*)"
}

# ============================================================
# 3. PARAMETER CLASSIFICATION
# ============================================================
def classify(param, value, gender="female"):
    if param not in REFERENCE_RANGES:
        return "Unknown"

    gender = gender.lower()
    ranges = REFERENCE_RANGES[param]

    if gender in ranges:
        low, high = ranges[gender]
    else:
        low, high = ranges["general"]

    if value < low:
        return "Low"
    elif value > high:
        return "High"
    return "Normal"

# ============================================================
# 4–6. INPUT PARSERS
# ============================================================
def parse_csv(file_path):
    return pd.read_csv(file_path)

def parse_json(file_path):
    with open(file_path) as f:
        return pd.DataFrame(json.load(f))

def parse_pdf_image(file_path):
    records = []
    images = convert_from_path(file_path) if file_path.endswith(".pdf") else [Image.open(file_path)]

    for img in images:
        text = pytesseract.image_to_string(img).lower()
        record = {}

        for param, pattern in CBC_PATTERNS.items():
            match = re.search(pattern, text)
            if match:
                record[param] = float(match.groups()[-1])

        age = re.search(r"age[:\s]+(\d+)", text)
        gender = re.search(r"(male|female)", text)

        record["Age"] = int(age.group(1)) if age else None
        record["Gender"] = gender.group(1).capitalize() if gender else "Female"

        if record:
            records.append(record)

    return pd.DataFrame(records)

# ============================================================
# 7. STANDARDIZATION + MODEL 1
# ============================================================
def standardize_and_classify(df):
    patients = []

    for _, row in df.iterrows():
        gender = row.get("Gender", "Female")
        patient = {"Age": row.get("Age"), "Gender": gender, "Parameters": {}}

        for param in REFERENCE_RANGES:
            if param in row and pd.notna(row[param]):
                patient["Parameters"][param] = {
                    "value": float(row[param]),
                    "status": classify(param, row[param], gender)
                }

        patients.append(patient)
    return patients

# ============================================================
# 8. PROCESS FILE
# ============================================================
def process_file(file_path):
    if file_path.endswith(".csv"):
        df = parse_csv(file_path)
    elif file_path.endswith(".json"):
        df = parse_json(file_path)
    else:
        df = parse_pdf_image(file_path)

    return standardize_and_classify(df)

# ============================================================
# 9. MODEL 2 — PATTERN RECOGNITION
# ============================================================
def analyze_patterns(patient):
    p = patient["Parameters"]
    findings, risks = [], []

    if "Hemoglobin" in p and "MCV" in p:
        if p["Hemoglobin"]["value"] < 12 and p["MCV"]["value"] < 80:
            findings.append("Microcytic anemia pattern detected.")
            risks.append("Anemia")

    if "White_Blood_Cells" in p and p["White_Blood_Cells"]["value"] > 11000:
        findings.append("Possible infection.")
        risks.append("Infection")

    return {"Findings": findings, "Risk_Flags": list(set(risks))}

# ============================================================
# 10. MODEL 3 — CONTEXTUAL ANALYSIS
# ============================================================
def contextual_analysis(patient, model2):
    findings = model2["Findings"].copy()
    if patient["Age"] and patient["Age"] > 60 and model2["Risk_Flags"]:
        findings.append("Advanced age increases clinical significance.")
    return {"Findings": findings, "Risk_Flags": model2["Risk_Flags"]}

# ============================================================
# ===================== MILESTONE 3 ==========================
# ============================================================

# 11. FINDINGS SYNTHESIS ENGINE
def synthesize_findings(patient, model3):
    summary = []

    if "Anemia" in model3["Risk_Flags"]:
        hb = patient["Parameters"]["Hemoglobin"]["value"]
        mcv = patient["Parameters"]["MCV"]["value"]
        summary.append(
            f"Low hemoglobin ({hb} g/dL) with reduced MCV ({mcv} fL suggests iron-deficiency anemia."
        )

    if not summary:
        summary.append("Blood parameters are within acceptable clinical limits.")

    return summary

# 12. PERSONALIZED RECOMMENDATION GENERATOR
def generate_recommendations(risks, age):
    recs = []

    if "Anemia" in risks:
        recs.extend([
            "Increase intake of iron-rich foods (spinach, legumes, red meat).",
            "Consult a physician before taking supplements.",
            "Repeat CBC test in 4–6 weeks."
        ])

    if age and age > 60:
        recs.append("Due to age, regular medical follow-up is recommended.")

    if not recs:
        recs.append("Maintain a balanced diet and regular physical activity.")

    recs.append("⚠️ AI-generated report — not a substitute for professional medical advice.")

    return recs

# 13. FINAL MILESTONE 3 REPORT

def generate_milestone_3_report(patient):
    model2 = analyze_patterns(patient)
    model3 = contextual_analysis(patient, model2)

    return {
        "Patient_Info": {
            "Age": patient.get("Age"),
            "Gender": patient.get("Gender")
        },
        "Parameter_Analysis": patient["Parameters"],
        "Clinical_Summary": synthesize_findings(patient, model3),
        "Risk_Flags": model3["Risk_Flags"],
        "Personalized_Recommendations": generate_recommendations(
            model3["Risk_Flags"], patient.get("Age")
        )
    }


# ============================================================
# 14. ORCHESTRATOR — MILESTONE 3
# ============================================================
def run_milestone_3(patients):
    return [generate_milestone_3_report(p) for p in patients]

# ============================================================
# 15. RUN
# ============================================================
if __name__ == "__main__":
    file_path = "/kaggle/input/reports/blood_count_dataset.csv"

    patients = process_file(file_path)
    final_reports = run_milestone_3(patients)

    with open("/kaggle/working/final_health_report.json", "w") as f:
        json.dump(final_reports, f, indent=4)

    print(json.dumps(final_reports, indent=4))
# Out:
# [
#     {
#         "Patient_Info": {
#             "Age": 68,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 10.4,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 5700.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 180000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 3.7,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 77.0,
#                 "status": "Low"
#             },
#             "MCH": {
#                 "value": 25.0,
#                 "status": "Low"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Low hemoglobin (10.4 g/dL) with reduced MCV (77.0 fL suggests iron-deficiency anemia."
#         ],
#         "Risk_Flags": [
#             "Anemia"
#         ],
#         "Personalized_Recommendations": [
#             "Increase intake of iron-rich foods (spinach, legumes, red meat).",
#             "Consult a physician before taking supplements.",
#             "Repeat CBC test in 4\u20136 weeks.",
#             "Due to age, regular medical follow-up is recommended.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 25,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.8,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7500.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 320000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.4,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 92.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 30.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 57,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.5,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 8500.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 370000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.1,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 90.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 28,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.7,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 7800.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 290000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.8,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 86.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 38,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.9,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8700.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 380000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.7,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 95.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 47,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.0,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 7000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 260000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.4,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 87.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 28.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 37,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.5,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8700.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 380000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.7,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 95.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 30,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.8,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 250000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.2,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 84.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 27.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 35,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.5,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7100.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 240000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.2,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 84.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 27.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 22,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.6,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7400.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 330000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.6,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 93.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 41,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.2,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 7700.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 310000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.6,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 88.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 34,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.8,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7300.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 280000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.3,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 85.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 28.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 40,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 15.2,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 9200.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 400000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.8,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 96.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 32.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 58,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.4,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 8900.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 390000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.7,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 94.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 34,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.8,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7300.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 280000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.3,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 85.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 28.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 50,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.0,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7600.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 330000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.0,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 90.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 64,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 10.7,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 5900.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 200000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 3.9,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 79.0,
#                 "status": "Low"
#             },
#             "MCH": {
#                 "value": 26.0,
#                 "status": "Low"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Low hemoglobin (10.7 g/dL) with reduced MCV (79.0 fL suggests iron-deficiency anemia."
#         ],
#         "Risk_Flags": [
#             "Anemia"
#         ],
#         "Personalized_Recommendations": [
#             "Increase intake of iron-rich foods (spinach, legumes, red meat).",
#             "Consult a physician before taking supplements.",
#             "Repeat CBC test in 4\u20136 weeks.",
#             "Due to age, regular medical follow-up is recommended.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 30,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.8,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 250000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.2,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 84.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 27.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 35,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.5,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8500.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 380000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.2,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 94.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 40,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 15.2,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 9200.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 400000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.8,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 96.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 32.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 52,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.2,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8300.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 370000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.4,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 92.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 70,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 10.2,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 5600.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 190000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 3.6,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 76.0,
#                 "status": "Low"
#             },
#             "MCH": {
#                 "value": 24.0,
#                 "status": "Low"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Low hemoglobin (10.2 g/dL) with reduced MCV (76.0 fL suggests iron-deficiency anemia."
#         ],
#         "Risk_Flags": [
#             "Anemia"
#         ],
#         "Personalized_Recommendations": [
#             "Increase intake of iron-rich foods (spinach, legumes, red meat).",
#             "Consult a physician before taking supplements.",
#             "Repeat CBC test in 4\u20136 weeks.",
#             "Due to age, regular medical follow-up is recommended.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 45,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.2,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 7200.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 270000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.6,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 88.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 28.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 63,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 10.8,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 5900.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 200000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 3.9,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 79.0,
#                 "status": "Low"
#             },
#             "MCH": {
#                 "value": 26.0,
#                 "status": "Low"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Low hemoglobin (10.8 g/dL) with reduced MCV (79.0 fL suggests iron-deficiency anemia."
#         ],
#         "Risk_Flags": [
#             "Anemia"
#         ],
#         "Personalized_Recommendations": [
#             "Increase intake of iron-rich foods (spinach, legumes, red meat).",
#             "Consult a physician before taking supplements.",
#             "Repeat CBC test in 4\u20136 weeks.",
#             "Due to age, regular medical follow-up is recommended.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 33,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.8,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8200.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 360000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.3,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 91.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 30.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 60,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.0,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 6000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 200000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.0,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 80.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 26.0,
#                 "status": "Low"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 41,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.2,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 7700.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 310000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.6,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 88.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 36,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.7,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8100.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 360000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.5,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 93.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 33,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.8,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8200.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 360000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.3,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 91.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 30.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 39,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 15.1,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 9000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 380000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.7,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 96.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 32.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 27,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.0,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 6900.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 230000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.3,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 85.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 28.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 35,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.7,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 6800.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 250000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.1,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 83.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 27.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 54,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.5,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 8000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 350000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.1,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 90.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 35,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.5,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7100.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 240000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.2,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 84.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 27.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 25,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.9,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7200.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 330000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.3,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 91.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 30.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 40,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.4,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8600.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 370000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.3,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 91.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 30.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 33,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.8,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 6800.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 250000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.2,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 84.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 27.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
# ...
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 96.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 32.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 37,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.5,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8700.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 380000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.7,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 95.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 38,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.9,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8700.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 380000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.7,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 95.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 26,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.5,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 7300.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 270000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.7,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 87.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 48,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.2,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7800.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 340000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.1,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 90.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 38,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.4,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 7600.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 310000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.7,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 88.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 28,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.6,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7800.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 310000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.6,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 93.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 40,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 12.5,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 7700.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 300000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.7,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 88.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 29.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 40,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 15.2,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 9200.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 400000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.8,
#                 "status": "High"
#             },
#             "MCV": {
#                 "value": 96.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 32.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 52,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 13.5,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 8000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 350000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.3,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 92.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 30.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 30,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.8,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 7000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 250000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.2,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 84.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 27.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 60,
#             "Gender": "Female"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 11.0,
#                 "status": "Low"
#             },
#             "White_Blood_Cells": {
#                 "value": 6000.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 200000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 4.0,
#                 "status": "Low"
#             },
#             "MCV": {
#                 "value": 80.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 26.0,
#                 "status": "Low"
#             },
#             "MCHC": {
#                 "value": 32.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     },
#     {
#         "Patient_Info": {
#             "Age": 46,
#             "Gender": "Male"
#         },
#         "Parameter_Analysis": {
#             "Hemoglobin": {
#                 "value": 14.2,
#                 "status": "Normal"
#             },
#             "White_Blood_Cells": {
#                 "value": 8300.0,
#                 "status": "Normal"
#             },
#             "Platelet_Count": {
#                 "value": 360000.0,
#                 "status": "Normal"
#             },
#             "Red_Blood_Cells": {
#                 "value": 5.4,
#                 "status": "Normal"
#             },
#             "MCV": {
#                 "value": 92.0,
#                 "status": "Normal"
#             },
#             "MCH": {
#                 "value": 31.0,
#                 "status": "Normal"
#             },
#             "MCHC": {
#                 "value": 33.0,
#                 "status": "Normal"
#             }
#         },
#         "Clinical_Summary": [
#             "Blood parameters are within acceptable clinical limits."
#         ],
#         "Risk_Flags": [],
#         "Personalized_Recommendations": [
#             "Maintain a balanced diet and regular physical activity.",
#             "\u26a0\ufe0f AI-generated report \u2014 not a substitute for professional medical advice."
#         ]
#     }
# ]
